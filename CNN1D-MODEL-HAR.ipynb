# %% [markdown]
# # There are 12 actions:
# **1	Jumping in place
# 2	Jumping jacks
# 3	Bending - hands up all the way down
# 4	Punching (boxing)
# 5	Waving - two hands
# 6	Waving - one hand (right)
# 7	Clapping hands
# 8	Throwing a ball
# 9	Sit down then stand up
# 10	Sit down
# 11	Stand up
# 12	T-pose**

# %% [markdown]
# # Data Storage Format
#
# - The files in database are in format of "txt".In txt files there are joint coordinates of 43 markers in human body in order.

# %% [markdown]
# # Let's start code!
# **First, we import pandas and os library.Then, we iterate over all txt files and collect all joint data with labels in a dataframe.Every row of dataframe is a action in a sample, and there are 129 xyz joint coordinates and 1 class label named 'classs' column.**

# %%
import pandas as pd
import os
path = '/kaggle/input/berkeley-multimodal-human-action-database/'

full_data = pd.DataFrame()

for entry in sorted(os.listdir(path)):
    if os.path.isfile(os.path.join(path, entry)):
        if entry.endswith('.txt'):
            data = pd.read_csv(path+entry,sep=' ',header=None)
            data.drop([129,130],inplace=True,axis=1)
            data['classs'] = entry[-10:-8]
            full_data = pd.concat([full_data,data],ignore_index=True)

# %% [markdown]
# **Let's check the data size of data.There are 2401920 rows(samples) and 130 features, last feature named 'classs' is label of that row.**

# %%
full_data.shape
# Out:
# (2401920, 130)

# %% [markdown]
# **When we check data types of the dataframe we can clearly see that first 129 rows are x,y,z features in format of float and the last column named 'classs' is object in string format which is labels.**

# %%
full_data.dtypes
# Out:
# 0         float64
# 1         float64
# 2         float64
# 3         float64
# 4         float64
#            ...
# 125       float64
# 126       float64
# 127       float64
# 128       float64
# classs     object
# Length: 130, dtype: object

# %% [markdown]
# **Let's have a look to data.**

# %%
full_data.head()
# Out:
#             0            1           2           3            4           5  \
# 0  535.633972  1596.885742  182.630203  638.731995  1557.109741  103.225571
# 1  535.525940  1597.152832  183.330444  638.749329  1557.116211  103.531601
# 2  535.596985  1597.039429  183.522781  638.780151  1557.109253  103.958931
# 3  535.639526  1597.143188  184.039703  638.775635  1557.160278  104.183563
# 4  535.655212  1597.121704  184.348969  638.669312  1557.312012  104.405937
#
#             6            7          8           9  ...         120  \
# 0  478.292816  1529.775635  36.972523  470.245300  ...  387.926392
# 1  478.020782  1530.198242  37.841022  470.252930  ...  387.690735
# 2  478.092926  1530.162109  37.929157  470.279816  ...  387.755524
# 3  477.950867  1530.371582  38.480976  470.298187  ...  387.915710
# 4  477.942841  1530.448730  38.754547  470.311096  ...  387.863953
#
#           121        122         123        124        125         126  \
# 0  151.815430  78.476036  400.183411  37.893978  49.051929  384.553955
# 1  151.693314  78.362648  400.167511  37.912468  49.064564  384.611206
# 2  151.714722  78.404068  400.146179  37.915264  49.033600  384.590485
# 3  151.737381  78.505905  400.148834  37.911430  49.032551  384.516388
# 4  151.710251  78.485397  400.103546  37.932167  49.079586  384.530640
#
#          127         128  classs
# 0  44.167561  119.841316      01
# 1  44.061180  119.831841      01
# 2  44.102978  119.838036      01
# 3  44.200638  119.834976      01
# 4  44.183495  119.837440      01
#
# [5 rows x 130 columns]

# %% [markdown]
# **In this section, I want to have a look to memory usage of dataframe.You know that kaggle provide us 16GB memory and this dataframe is quaite big.I just wanted to see that "can kaggle hardware handle this?"**

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401920 entries, 0 to 2401919
# Columns: 130 entries, 0 to classs
# dtypes: float64(129), object(1)
# memory usage: 2.3+ GB

# %% [markdown]
# **In this section, we split data as features and label."x" variable is features and "y" variable is label of that features in order.**

# %%
x = full_data.drop(["classs"],axis=1)
y = full_data.classs.values
x.head()
# Out:
#           0            1           2           3            4           5    \
# 0  535.633972  1596.885742  182.630203  638.731995  1557.109741  103.225571
# 1  535.525940  1597.152832  183.330444  638.749329  1557.116211  103.531601
# 2  535.596985  1597.039429  183.522781  638.780151  1557.109253  103.958931
# 3  535.639526  1597.143188  184.039703  638.775635  1557.160278  104.183563
# 4  535.655212  1597.121704  184.348969  638.669312  1557.312012  104.405937
#
#           6            7          8           9    ...        119         120  \
# 0  478.292816  1529.775635  36.972523  470.245300  ...  82.758965  387.926392
# 1  478.020782  1530.198242  37.841022  470.252930  ...  82.767532  387.690735
# 2  478.092926  1530.162109  37.929157  470.279816  ...  82.805794  387.755524
# 3  477.950867  1530.371582  38.480976  470.298187  ...  82.827797  387.915710
# 4  477.942841  1530.448730  38.754547  470.311096  ...  82.962585  387.863953
#
#           121        122         123        124        125         126  \
# 0  151.815430  78.476036  400.183411  37.893978  49.051929  384.553955
# 1  151.693314  78.362648  400.167511  37.912468  49.064564  384.611206
# 2  151.714722  78.404068  400.146179  37.915264  49.033600  384.590485
# 3  151.737381  78.505905  400.148834  37.911430  49.032551  384.516388
# 4  151.710251  78.485397  400.103546  37.932167  49.079586  384.530640
#
#          127         128
# 0  44.167561  119.841316
# 1  44.061180  119.831841
# 2  44.102978  119.838036
# 3  44.200638  119.834976
# 4  44.183495  119.837440
#
# [5 rows x 129 columns]

# %% [markdown]
# **("y") Label data is in format of string,for 01-11 classes are basicly can be convertable to integer.But 12th class is like "t-" which is a string.So in this section we replace "t-" with "12" and convert it to integer.**

# %%
y = pd.DataFrame(y)
y.iloc[:,0] = y.iloc[:,0].str.replace('t','1')
y.iloc[:,0] = y.iloc[:,0].str.replace('-','2')
y.astype('int32')
# Out:
#           0
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...      ..
# 2401915  12
# 2401916  12
# 2401917  12
# 2401918  12
# 2401919  12
#
# [2401920 rows x 1 columns]

# %% [markdown]
# **Now, we can split data as train and test data.**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,shuffle=True)

print('Shape of train data is : ',x_train.shape)
print('Shape of label data is : ',y_train.shape)
# Out:
# Shape of train data is :  (1801440, 129)
# Shape of label data is :  (1801440, 1)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Input, Dense, Conv1D, Flatten, Dropout
from keras.models import Model
from keras.layers import Reshape

# Define input layer
input_layer = Input(shape=(129,))

# Reshape layer if needed
reshaped_input = Reshape((129, 1))(input_layer)

# Convolutional layers
conv1 = Conv1D(64, kernel_size=3, activation='relu')(reshaped_input)
conv2 = Conv1D(128, kernel_size=3, activation='relu')(conv1)

# Flatten layer
flat = Flatten()(conv2)

# Dense layers with dropout
dense1 = Dense(256, activation='relu')(flat)
dropout1 = Dropout(0.5)(dense1)

dense2 = Dense(128, activation='relu')(dropout1)
dropout2 = Dropout(0.5)(dense2)

# Output layer
output_layer = Dense(13, activation='softmax')(dropout2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 129)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 129, 1)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 127, 64)           256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 125, 128)          24704
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4096256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 13)                1677
# =================================================================
# Total params: 4,155,789
# Trainable params: 4,155,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
hist = model.fit(x_train, y_train, epochs=10, validation_split=0.20, batch_size=64)
# Out:
# Train on 1441152 samples, validate on 360288 samples
# Epoch 1/10
# 1441152/1441152 [==============================] - 1293s 897us/step - loss: 0.7561 - accuracy: 0.7801 - val_loss: 0.3231 - val_accuracy: 0.8805
# Epoch 2/10
# 1441152/1441152 [==============================] - 1294s 898us/step - loss: 0.4253 - accuracy: 0.8564 - val_loss: 0.3000 - val_accuracy: 0.8881
# Epoch 3/10
# 1441152/1441152 [==============================] - 1299s 901us/step - loss: 0.3849 - accuracy: 0.8700 - val_loss: 0.2520 - val_accuracy: 0.9029
# Epoch 4/10
# 1441152/1441152 [==============================] - 1358s 943us/step - loss: 0.3620 - accuracy: 0.8794 - val_loss: 0.3528 - val_accuracy: 0.8820
# Epoch 5/10
# 1441152/1441152 [==============================] - 1358s 942us/step - loss: 0.3448 - accuracy: 0.8868 - val_loss: 0.2764 - val_accuracy: 0.9086
# Epoch 6/10
# 1441152/1441152 [==============================] - 1352s 938us/step - loss: 0.3356 - accuracy: 0.8908 - val_loss: 0.1706 - val_accuracy: 0.9381
# Epoch 7/10
# 1441152/1441152 [==============================] - 1359s 943us/step - loss: 0.3273 - accuracy: 0.8951 - val_loss: 0.2268 - val_accuracy: 0.9145
# Epoch 8/10
# 1441152/1441152 [==============================] - 1318s 914us/step - loss: 0.3192 - accuracy: 0.8985 - val_loss: 0.1488 - val_accuracy: 0.9455
# Epoch 9/10
# 1441152/1441152 [==============================] - 1365s 947us/step - loss: 0.3383 - accuracy: 0.8932 - val_loss: 0.1655 - val_accuracy: 0.9408
# Epoch 10/10
# 1441152/1441152 [==============================] - 1358s 942us/step - loss: 0.3278 - accuracy: 0.8972 - val_loss: 0.1692 - val_accuracy: 0.9382

# %%
from matplotlib import pyplot as plt
print(hist.history.keys())

plt.plot(hist.history['loss'],label = 'Train loss')
plt.plot(hist.history['val_loss'],label = 'Val loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
# Assuming 'accuracy' is one of the metrics specified when compiling the model
evaluation_results = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {evaluation_results[1] * 100:.2f}%')
# Out:
# 600480/600480 [==============================] - 145s 242us/step
# Test Accuracy: 93.80%

# %%
print(hist.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have the 'hist' object from model training
# Extract training predictions
y_train_pred = np.argmax(model.predict(x_train), axis=1)

# Extract training true labels
y_train_true = np.argmax(y_train, axis=1)

# Compute confusion matrix for training
conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)

# Print confusion matrix for training
print("Confusion Matrix - Training:")
print(conf_matrix_train)

# Compute and print classification report for training
print("\nClassification Report - Training:")
print(classification_report(y_train_true, y_train_pred))
# Out:
# Confusion Matrix - Training:
# [[104095   1190     81     82    351    241    257      0    818      0
#        1      0]
#  [  6547 130965    384     24    792    404    594      4    262      0
#        0      0]
#  [   329    457 324045     70   5289    338   2739      0     10      0
#        0    148]
#  [   534    108     87 170533   1101    550   5334     13      0      0
#        0      3]
#  [    59      0    117     29 180916    408   1130      2      0      0
#        0     94]
#  [     3      4     68     11   8466 180849    879     34     99      0
#        0      0]
#  [    77     30    120     38   1028    185  92930      1     27      0
#        0      0]
#  [   286      0    515    213     50      3     47  63524      0      0
#        0      0]
#  [     0      0      0      0      0      3      0      0 373101     54
#      414      0]
#  [     1      2      0      0      0      2      0      0  34123  26478
#     4044      0]
#  [     0      0      0      0      0      0      0      0  26920    775
#    23870      0]
#  [     0      0      0      0      0   1613      0      0      0      0
#        0  19018]]
#
# Classification Report - Training:
#               precision    recall  f1-score   support
#
#            1       0.93      0.97      0.95    107116
#            2       0.99      0.94      0.96    139976
#            3       1.00      0.97      0.98    333425
#            4       1.00      0.96      0.98    178263
#            5       0.91      0.99      0.95    182755
#            6       0.98      0.95      0.96    190413
#            7       0.89      0.98      0.94     94436
#            8       1.00      0.98      0.99     64638
#            9       0.86      1.00      0.92    373572
#           10       0.97      0.41      0.58     64650
#           11       0.84      0.46      0.60     51565
#           12       0.99      0.92      0.95     20631
#
#     accuracy                           0.94   1801440
#    macro avg       0.95      0.88      0.90   1801440
# weighted avg       0.94      0.94      0.93   1801440

# %%
# Plot training loss
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
